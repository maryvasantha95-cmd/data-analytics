# %%
# !pip install fastf1
# Out:
# Requirement already satisfied: fastf1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (3.6.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (3.10.3)
# Requirement already satisfied: numpy<3.0.0,>=1.23.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (2.3.0)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (2.3.0)
# Requirement already satisfied: python-dateutil in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (2.9.0.post0)
# Requirement already satisfied: rapidfuzz in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (3.13.0)
# Requirement already satisfied: requests-cache>=1.0.0 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (1.2.1)
# Requirement already satisfied: requests>=2.28.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.8.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (1.16.0)
# Requirement already satisfied: timple>=0.1.6 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (0.1.8)
# Requirement already satisfied: websockets<14,>=10.3 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from fastf1) (13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil->fastf1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.1->fastf1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.1->fastf1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.1->fastf1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.1->fastf1) (2025.4.26)
# Requirement already satisfied: attrs>=21.2 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests-cache>=1.0.0->fastf1) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests-cache>=1.0.0->fastf1) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests-cache>=1.0.0->fastf1) (4.3.8)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from requests-cache>=1.0.0->fastf1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hi\appdata\local\programs\python\python313\lib\site-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (4.14.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fastf1
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import fastf1
from fastf1 import plotting
import requests
import fastf1.plotting
import seaborn as sns
from matplotlib import colormaps
from matplotlib.collections import LineCollection
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import psycopg2
from matplotlib import cm
print(fastf1.__version__)
# Out:
# 3.6.0

# %%
class FastF1:
    def __init__(self, year, event_name, session_type):
        """
        Initializes the FastF1 object by retrieving the session for the given year, event, and session type.
        """
        self.year = year
        self.event_name = event_name
        self.session_type = session_type
        self.session = fastf1.get_session(year, event_name, session_type)
        self.laps = None

    def load_session(self):
        """Loads the session data into memory and stores the laps DataFrame."""
        self.session.load()
        self.laps = self.session.laps

    def session_event(self):
        """Returns the event information object for the loaded session."""
        return self.session.event

    def lap_info(self):
        """Provides a summary info of the laps DataFrame."""
        return self.laps.info()

    def fastest_lap(self):
        """Retrieves the fastest lap from the loaded laps DataFrame."""
        return self.laps.pick_fastest()

    def value_count(self):
        """Counts laps grouped by tyre compound used in the session."""
        return self.session.laps['Compound'].value_counts()

    def stint_analysis(self):
        """Counts the number of laps per driver per stint."""
        return self.laps.groupby(['Driver', 'Stint'])['LapNumber'].count()

    def null_percent(self):
        """Calculates the percentage of null values for each column."""
        return self.laps.isnull().mean() * 100

    def sector_time_comparison(self):
        """Fastest sector times (S1, S2, S3) in seconds per driver."""
        df = self.session.laps
        fastest = df.groupby('Driver')[['Sector1Time','Sector2Time','Sector3Time']].min()
        fastest = fastest.apply(lambda x: x.dt.total_seconds())
        return fastest.sort_values(by='Sector1Time')

    def avg_laptime(self):
        """Average lap time per driver in seconds."""
        df = self.session.laps
        avg_laptime = df.groupby('Driver')['LapTime'].mean()
        avg_laptime = avg_laptime.apply(lambda x: x.total_seconds())
        return avg_laptime.sort_values()

    def fastest_laptime(self):
        """Fastest lap time per driver and team in seconds."""
        df = self.session.laps
        min_laptime = df.groupby(['Driver','Team'])['LapTime'].min()
        return min_laptime.apply(lambda x: x.total_seconds()).sort_values()

    def pit_stop_count(self):
        """Number of pit stops per driver."""
        df = self.session.laps
        pit_counts = df[df['PitInTime'].notna()].groupby('Driver')['PitInTime'].count()
        return pit_counts.sort_values()

    def compound_data(self):
        """Filters laps for 'SOFT', 'MEDIUM', 'HARD' tyres and returns relevant columns."""
        return self.laps[self.laps['Compound'].isin(['SOFT','MEDIUM','HARD'])][['Compound','TyreLife','FreshTyre']]

    def plot_tyre_life_distribution(self):
        data = self.compound_data()
        plt.figure(figsize=(10,6))
        sns.boxplot(data=data, x='Compound', y='TyreLife', palette='coolwarm')
        plt.title('Tyre Life Distribution by Compound')
        plt.ylabel('Tyre Life (laps)')
        plt.xlabel('Tyre Compound')
        plt.xticks(rotation=45)
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    def plot_avg_tyre_life(self):
        avg_life = self.laps.groupby('Compound')['TyreLife'].mean().reset_index()
        plt.figure(figsize=(8,5))
        sns.barplot(data=avg_life, x='Compound', y='TyreLife', palette='Set2')
        plt.title('Average Tyre Life by Compound')
        plt.ylabel('Average Tyre Life (laps)')
        plt.xlabel('Tyre Compound')
        plt.xticks(rotation=45)
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    def plot_fresh_vs_used_tyres(self):
        compound_fresh_counts = self.laps.groupby(['Compound','FreshTyre']).size().unstack(fill_value=0)
        compound_fresh_counts.plot(kind='bar', stacked=True, figsize=(10,6), colormap='Set3')
        plt.title('Fresh vs Used Tyres per Compound')
        plt.xlabel('Tyre Compound')
        plt.ylabel('Count')
        plt.xticks(rotation=45)
        plt.legend(title='Fresh Tyre (1=Fresh, 0=Used)')
        plt.tight_layout()
        plt.show()

    def driver_position_chart(self):
        df = self.session.laps
        df = df[df['Position'].notnull()]
        plt.figure(figsize=(12,6))
        for driver in df['Driver'].unique():
            driver_data = df[df['Driver']==driver]
            plt.plot(driver_data['LapNumber'], driver_data['Position'], label=driver)
            plt.text(driver_data['LapNumber'].iloc[-1]+0.2, driver_data['Position'].iloc[-1], driver,
                     verticalalignment='center')
        plt.gca().invert_yaxis()
        plt.xlabel("Lap")
        plt.ylabel("Position")
        plt.title(f"{self.session.event['EventName']} {self.year} - Position Changes")
        plt.tight_layout()
        plt.show()

    def compare_speed_overlay(self, driver1, driver2):
        lap1 = self.session.laps.pick_drivers(driver1).pick_fastest()
        lap2 = self.session.laps.pick_drivers(driver2).pick_fastest()
        tel1 = lap1.get_car_data().add_distance()
        tel2 = lap2.get_car_data().add_distance()
        plt.figure(figsize=(12,6))
        plt.plot(tel1['Distance'], tel1['Speed'], label=driver1)
        plt.plot(tel2['Distance'], tel2['Speed'], label=driver2)
        plt.xlabel('Distance (m)')
        plt.ylabel('Speed (km/h)')
        plt.title(f"Speed Comparison: {driver1} vs {driver2}")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    def plot_fastest_lap_gear_shifts(self):
        lap = self.session.laps.pick_fastest()
        tel = lap.get_telemetry()
        x = tel['X'].values
        y = tel['Y'].values
        points = np.array([x,y]).T.reshape(-1,1,2)
        segments = np.concatenate([points[:-1],points[1:]], axis=1)
        gear = tel['nGear'].to_numpy().astype(float)
        cmap = cm.get_cmap('Paired')
        lc_comp = LineCollection(segments, cmap=cmap, norm=plt.Normalize(1,9))
        lc_comp.set_array(gear)
        lc_comp.set_linewidth(4)
        plt.figure(figsize=(12,8))
        plt.gca().add_collection(lc_comp)
        plt.axis('equal')
        plt.tick_params(labelleft=False,left=False,labelbottom=False,bottom=False)
        plt.suptitle(f"Fastest Lap Gear Shift Visualization\n{lap['Driver']} - {self.session.event['EventName']} {self.session.event.year}")
        cbar = plt.colorbar(lc_comp, label="Gear", boundaries=np.arange(1,10))
        cbar.set_ticks(np.arange(1.5,9.5))
        cbar.set_ticklabels(np.arange(1,9))
        plt.show()

    def plot_driver_fastest_lap_speed(self, driver, colormap='viridis', weekend_name=None):
        lap = self.session.laps.pick_drivers(driver).pick_fastest()
        tel = lap.get_telemetry()
        x = tel['X'].values
        y = tel['Y'].values
        color = tel['Speed'].values
        points = np.array([x,y]).T.reshape(-1,1,2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        fig, ax = plt.subplots(figsize=(12,6.75))
        title_str = f'{weekend_name or self.session.event["EventName"]} {self.year} - {driver} - Speed'
        fig.suptitle(title_str, size=20, y=0.95)
        norm = plt.Normalize(color.min(), color.max())
        lc = LineCollection(segments, cmap=plt.get_cmap(colormap), norm=norm, linewidth=5)
        lc.set_array(color)
        ax.add_collection(lc)
        cbar = plt.colorbar(lc, ax=ax, orientation='horizontal', pad=0.1)
        cbar.set_label('Speed (km/h)')
        ax.axis('off')
        plt.show()

    # ---------------- PostgreSQL Methods ---------------- #

    @staticmethod
    def pg_type_from_dtype(dtype_str):
        if 'int' in dtype_str:
            return 'INTEGER'
        elif 'float' in dtype_str:
            return 'FLOAT'
        elif 'datetime' in dtype_str:
            return 'TIMESTAMP'
        elif 'bool' in dtype_str:
            return 'BOOLEAN'
        else:
            return 'TEXT'

    def create_table_if_not_exists(self, db_params, table_name="fastf1_data"):
        laps_df = self.laps.copy()
        for col in laps_df.select_dtypes(include=["timedelta"]).columns:
            laps_df[col] = laps_df[col].dt.total_seconds()
        columns = [f'"{col}" {self.pg_type_from_dtype(str(laps_df[col].dtype))}' for col in laps_df.columns]
        create_stmt = f"CREATE TABLE IF NOT EXISTS {table_name} ({', '.join(columns)});"
        conn = psycopg2.connect(**db_params)
        cur = conn.cursor()
        cur.execute(create_stmt)
        conn.commit()
        cur.close()
        conn.close()
        print(f"✅ Table '{table_name}' ensured in PostgreSQL")

    def insert_laps_to_postgres(self, db_params, table_name="fastf1_data"):
        self.create_table_if_not_exists(db_params, table_name)
        laps_df = self.laps.copy()
        for col in laps_df.select_dtypes(include=["timedelta"]).columns:
            laps_df[col] = laps_df[col].dt.total_seconds()
        laps_df = laps_df.replace({np.nan: None, pd.NaT: None})
        columns = list(laps_df.columns)
        placeholders = ', '.join(['%s']*len(columns))
        insert_stmt = f'INSERT INTO {table_name} ({", ".join(["\"{}\"".format(col) for col in columns])}) VALUES ({placeholders});'
        conn = psycopg2.connect(**db_params)
        cur = conn.cursor()
        for _, row in laps_df.iterrows():
            cur.execute(insert_stmt, tuple([None if pd.isna(v) else v for v in row]))
        conn.commit()
        cur.close()
        conn.close()
        print(f"✅ Laps data inserted into '{table_name}'")

    def read_from_postgresql(self, conn_params, table_name="fastf1_data"):
        """
        Reads race or lap data from PostgreSQL and returns it as a pandas DataFrame.
        Also saves CSV automatically.
        """
        try:
            conn = psycopg2.connect(**conn_params)
            query = f"SELECT * FROM {table_name};"
            df = pd.read_sql(query, conn)
            conn.close()
            print(f"✅ Data successfully read from PostgreSQL table '{table_name}'")
            file_name = f"{self.year}_{self.event_name}_{self.session_type}_race_data.csv"
            df.to_csv(file_name, index=False)
            print(f"💾 Data saved as '{file_name}'")
            return df
        except Exception as e:
            print("⚠️ Error reading from PostgreSQL:", e)
            return None

# %%
f1 = FastF1(2023, 'Belgium', 'R')
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (208.4 MB) C:\Users\hi\AppData\Local\Temp\fastf1

# %%
f1.load_session()
# Out:
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '44', '14', '63', '4', '31', '18', '22', '10', '77', '24', '23', '20', '3', '2', '27', '55', '81']

# %%
f1.laps  # LapsDataFrame with all lap details
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 01:04:40.474000    VER            1 0 days 00:01:55.659000
# 1   0 days 01:06:33.577000    VER            1 0 days 00:01:53.103000
# 2   0 days 01:08:25.854000    VER            1 0 days 00:01:52.277000
# 3   0 days 01:10:18.643000    VER            1 0 days 00:01:52.789000
# 4   0 days 01:12:11.245000    VER            1 0 days 00:01:52.602000
# ..                     ...    ...          ...                    ...
# 811 0 days 01:41:37.186000    SAI           55 0 days 00:01:56.426000
# 812 0 days 01:43:37.348000    SAI           55 0 days 00:02:00.162000
# 813 0 days 01:45:35.297000    SAI           55 0 days 00:01:57.949000
# 814 0 days 01:47:38.660000    SAI           55 0 days 00:02:03.363000
# 815 0 days 01:04:38.110000    PIA           81                    NaT
#
#      LapNumber  Stint PitOutTime              PitInTime  \
# 0          1.0    1.0        NaT                    NaT
# 1          2.0    1.0        NaT                    NaT
# 2          3.0    1.0        NaT                    NaT
# 3          4.0    1.0        NaT                    NaT
# 4          5.0    1.0        NaT                    NaT
# ..         ...    ...        ...                    ...
# 811       20.0    2.0        NaT                    NaT
# 812       21.0    2.0        NaT                    NaT
# 813       22.0    2.0        NaT                    NaT
# 814       23.0    2.0        NaT 0 days 01:47:34.913000
# 815        1.0    1.0        NaT                    NaT
#
#                Sector1Time            Sector2Time  ... FreshTyre  \
# 0                      NaT 0 days 00:00:49.787000  ...      True
# 1   0 days 00:00:32.291000 0 days 00:00:50.712000  ...      True
# 2   0 days 00:00:31.758000 0 days 00:00:50.325000  ...      True
# 3   0 days 00:00:31.881000 0 days 00:00:50.599000  ...      True
# 4   0 days 00:00:32.001000 0 days 00:00:50.201000  ...      True
# ..                     ...                    ...  ...       ...
# 811 0 days 00:00:32.648000 0 days 00:00:52.419000  ...      True
# 812 0 days 00:00:32.787000 0 days 00:00:54.760000  ...      True
# 813 0 days 00:00:32.936000 0 days 00:00:53.638000  ...      True
# 814 0 days 00:00:32.748000 0 days 00:00:52.157000  ...      True
# 815                    NaT                    NaT  ...      True
#
#                 Team           LapStartTime            LapStartDate  \
# 0    Red Bull Racing 0 days 01:02:44.614000 2023-07-30 13:03:45.833
# 1    Red Bull Racing 0 days 01:04:40.474000 2023-07-30 13:05:41.693
# 2    Red Bull Racing 0 days 01:06:33.577000 2023-07-30 13:07:34.796
# 3    Red Bull Racing 0 days 01:08:25.854000 2023-07-30 13:09:27.073
# 4    Red Bull Racing 0 days 01:10:18.643000 2023-07-30 13:11:19.862
# ..               ...                    ...                     ...
# 811          Ferrari 0 days 01:39:40.760000 2023-07-30 13:40:41.979
# 812          Ferrari 0 days 01:41:37.186000 2023-07-30 13:42:38.405
# 813          Ferrari 0 days 01:43:37.348000 2023-07-30 13:44:38.567
# 814          Ferrari 0 days 01:45:35.297000 2023-07-30 13:46:36.516
# 815          McLaren 0 days 01:02:44.614000 2023-07-30 13:03:45.833
#
#      TrackStatus  Position  Deleted                    DeletedReason  \
# 0              1       4.0    False
# 1             12       4.0    False
# 2             21       4.0    False
# 3              1       4.0    False
# 4              1       4.0    False
# ..           ...       ...      ...                              ...
# 811            1      19.0    False
# 812            1      19.0     True  TRACK LIMITS AT TURN 11 LAP 21
# 813            1      19.0    False
# 814            1      19.0    False
# 815            1       NaN    False
#
#      FastF1Generated IsAccurate
# 0              False      False
# 1              False       True
# 2              False       True
# 3              False       True
# 4              False       True
# ..               ...        ...
# 811            False       True
# 812            False       True
# 813            False       True
# 814            False      False
# 815             True      False
#
# [816 rows x 31 columns]

# %%
f1.session_event()  # Prints event details
# Out:
# RoundNumber                                                     12
# Country                                                    Belgium
# Location                                         Spa-Francorchamps
# OfficialEventName    FORMULA 1 MSC CRUISES BELGIAN GRAND PRIX 2023
# EventDate                                      2023-07-30 00:00:00
# EventName                                       Belgian Grand Prix
# EventFormat                                        sprint_shootout
# Session1                                                Practice 1
# Session1Date                             2023-07-28 13:30:00+02:00
# Session1DateUtc                                2023-07-28 11:30:00
# Session2                                                Qualifying
# Session2Date                             2023-07-28 17:00:00+02:00
# Session2DateUtc                                2023-07-28 15:00:00
# Session3                                           Sprint Shootout
# Session3Date                             2023-07-29 12:00:00+02:00
# Session3DateUtc                                2023-07-29 10:00:00
# Session4                                                    Sprint
# Session4Date                             2023-07-29 17:05:00+02:00
# Session4DateUtc                                2023-07-29 15:05:00
# Session5                                                      Race
# Session5Date                             2023-07-30 15:00:00+02:00
# Session5DateUtc                                2023-07-30 13:00:00
# F1ApiSupport                                                  True
# Name: 12, dtype: object

# %%
f1.lap_info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                816 non-null    timedelta64[ns]
#  1   Driver              816 non-null    object
#  2   DriverNumber        816 non-null    object
#  3   LapTime             815 non-null    timedelta64[ns]
#  4   LapNumber           816 non-null    float64
#  5   Stint               816 non-null    float64
#  6   PitOutTime          38 non-null     timedelta64[ns]
#  7   PitInTime           38 non-null     timedelta64[ns]
#  8   Sector1Time         796 non-null    timedelta64[ns]
#  9   Sector2Time         815 non-null    timedelta64[ns]
#  10  Sector3Time         815 non-null    timedelta64[ns]
#  11  Sector1SessionTime  796 non-null    timedelta64[ns]
#  12  Sector2SessionTime  815 non-null    timedelta64[ns]
#  13  Sector3SessionTime  815 non-null    timedelta64[ns]
#  14  SpeedI1             726 non-null    float64
#  15  SpeedI2             815 non-null    float64
#  16  SpeedFL             777 non-null    float64
#  17  SpeedST             671 non-null    float64
#  18  IsPersonalBest      816 non-null    bool
#  19  Compound            816 non-null    object
#  20  TyreLife            816 non-null    float64
#  21  FreshTyre           816 non-null    bool
#  22  Team                816 non-null    object
#  23  LapStartTime        816 non-null    timedelta64[ns]
#  24  LapStartDate        816 non-null    datetime64[ns]
#  25  TrackStatus         816 non-null    object
#  26  Position            815 non-null    float64
#  27  Deleted             816 non-null    bool
#  28  DeletedReason       816 non-null    object
#  29  FastF1Generated     816 non-null    bool
#  30  IsAccurate          816 non-null    bool
# dtypes: bool(5), datetime64[ns](1), float64(8), object(6), timedelta64[ns](11)
# memory usage: 169.9+ KB

# %%
f1.value_count()
# Out:
# Compound
# MEDIUM    419
# SOFT      385
# HARD       12
# Name: count, dtype: int64

# %%
f1.stint_analysis()
# Out:
# Driver  Stint
# ALB     1.0       7
#         2.0      16
#         3.0      10
#         4.0      11
# ALO     1.0      10
#         2.0      19
#         3.0      15
# BOT     1.0       6
#         2.0      18
#         3.0      20
# GAS     1.0      23
#         2.0      21
# HAM     1.0      12
#         2.0      15
#         3.0      15
#         4.0       2
# HUL     1.0      12
#         2.0      12
#         3.0      20
# LEC     1.0      13
#         2.0      15
#         3.0      16
# MAG     1.0       5
#         2.0      20
#         3.0      19
# NOR     1.0       5
#         2.0      12
#         3.0      27
# OCO     1.0       6
#         2.0      19
#         3.0      19
# PER     1.0      13
#         2.0      16
#         3.0      15
# PIA     1.0       1
# RIC     1.0       5
#         2.0      17
#         3.0      22
# RUS     1.0      22
#         2.0      22
# SAI     1.0       7
#         2.0      16
# SAR     1.0       8
#         2.0      16
#         3.0      10
#         4.0      10
# STR     1.0      20
#         2.0      24
# TSU     1.0       9
#         2.0      15
#         3.0      20
# VER     1.0      14
#         2.0      16
#         3.0      14
# ZHO     1.0       7
#         2.0      18
#         3.0      19
# Name: LapNumber, dtype: int64

# %%
f1.null_percent()
# Out:
# Time                   0.000000
# Driver                 0.000000
# DriverNumber           0.000000
# LapTime                0.122549
# LapNumber              0.000000
# Stint                  0.000000
# PitOutTime            95.343137
# PitInTime             95.343137
# Sector1Time            2.450980
# Sector2Time            0.122549
# Sector3Time            0.122549
# Sector1SessionTime     2.450980
# Sector2SessionTime     0.122549
# Sector3SessionTime     0.122549
# SpeedI1               11.029412
# SpeedI2                0.122549
# SpeedFL                4.779412
# SpeedST               17.769608
# IsPersonalBest         0.000000
# Compound               0.000000
# TyreLife               0.000000
# FreshTyre              0.000000
# Team                   0.000000
# LapStartTime           0.000000
# LapStartDate           0.000000
# TrackStatus            0.000000
# Position               0.122549
# Deleted                0.000000
# DeletedReason          0.000000
# FastF1Generated        0.000000
# IsAccurate             0.000000
# dtype: float64

# %%
f1.avg_laptime()
# Out:
# Driver
# VER    112.510227
# PER    113.017159
# LEC    113.243386
# HAM    113.639113
# ALO    113.787136
# RUS    113.944340
# NOR    114.185659
# OCO    114.208386
# STR    114.313409
# TSU    114.333431
# GAS    114.398500
# BOT    114.446386
# ZHO    114.679340
# ALB    114.696227
# MAG    114.822818
# RIC    114.852750
# SAR    114.884681
# HUL    115.020454
# SAI    117.123695
# PIA           NaN
# Name: LapTime, dtype: float64

# %%
f1.fastest_laptime()
# Out:
# Driver  Team
# HAM     Mercedes           107.305
# VER     Red Bull Racing    108.922
# ALB     Williams           109.841
# HUL     Haas F1 Team       109.907
# ZHO     Alfa Romeo         110.188
# SAR     Williams           110.236
# PER     Red Bull Racing    110.308
# LEC     Ferrari            110.436
# OCO     Alpine             110.439
# BOT     Alfa Romeo         110.515
# RUS     Mercedes           110.603
# GAS     Alpine             110.911
# ALO     Aston Martin       110.938
# MAG     Haas F1 Team       110.993
# RIC     AlphaTauri         110.994
# STR     Aston Martin       111.297
# TSU     AlphaTauri         111.394
# NOR     McLaren            111.682
# SAI     Ferrari            113.138
# PIA     McLaren                NaN
# Name: LapTime, dtype: float64

# %%
f1.sector_time_comparison()
# Out:
#         Sector1Time  Sector2Time  Sector3Time
# Driver
# OCO          31.249       48.604       30.005
# HUL          31.307       48.733       29.867
# ALB          31.336       48.936       29.513
# SAR          31.404       48.766       29.566
# GAS          31.455       49.224       29.858
# HAM          31.545       46.470       29.290
# RIC          31.555       49.417       30.022
# ZHO          31.560       48.488       29.771
# RUS          31.572       48.639       29.894
# VER          31.588       47.017       29.551
# ALO          31.702       48.452       30.064
# TSU          31.735       49.438       29.757
# BOT          31.741       48.103       29.705
# MAG          31.748       49.060       29.920
# SAI          31.999       50.217       30.167
# STR          32.076       48.728       30.014
# LEC          32.085       47.434       29.821
# PER          32.265       48.099       29.828
# NOR          32.307       48.356       30.260
# PIA             NaN          NaN          NaN

# %%
f1.pit_stop_count()
# Out:
# Driver
# GAS    1
# STR    1
# RUS    1
# ALO    2
# MAG    2
# LEC    2
# BOT    2
# HUL    2
# RIC    2
# PER    2
# NOR    2
# OCO    2
# SAI    2
# ZHO    2
# VER    2
# TSU    2
# SAR    3
# HAM    3
# ALB    3
# Name: PitInTime, dtype: int64

# %%
f1.compound_data()
# Out:
#     Compound  TyreLife  FreshTyre
# 0       SOFT       1.0       True
# 1       SOFT       2.0       True
# 2       SOFT       3.0       True
# 3       SOFT       4.0       True
# 4       SOFT       5.0       True
# ..       ...       ...        ...
# 811   MEDIUM      13.0       True
# 812   MEDIUM      14.0       True
# 813   MEDIUM      15.0       True
# 814   MEDIUM      16.0       True
# 815   MEDIUM       1.0       True
#
# [816 rows x 3 columns]

# %%
f1.driver_position_chart()

# %%
f1.compare_speed_overlay("GAS","PER")

# %%
f1.plot_fastest_lap_gear_shifts() # Fastest lap gear shift visualization
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4332\3522551137.py:159: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Paired')

# %%
f1.plot_driver_fastest_lap_speed('VER')

# %%
f1.plot_tyre_life_distribution()
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4332\3522551137.py:81: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Compound', y='TyreLife', palette='coolwarm')

# %%
f1.plot_avg_tyre_life()
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4332\3522551137.py:93: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_life, x='Compound', y='TyreLife', palette='Set2')

# %%
f1.plot_fresh_vs_used_tyres()

# %%
f1.pg_type_from_dtype('dtype_str')
# Out:
# 'TEXT'

# %%
# Your PostgreSQL connection parameters
db_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "901473R",
    "host": "localhost",
    "port": "5432"
}

# Example: Load race data using FastF1
f1 = FastF1(2023, "Belgium", "R")   # Year, Event, Session Type
laps_df = f1.load_session()          # Load race data (laps DataFrame)

# Save to PostgreSQL
f1.insert_laps_to_postgres(db_params, table_name="fastf1_race_data")

# Read from PostgreSQL (optional, like music.read_from_postgresql)
race_data = f1.read_from_postgresql(db_params, table_name="fastf1_race_data")

# Save the retrieved data as CSV file
race_data.to_csv("fastf1_race_data.csv", index=False)
print("✅ FastF1 race data saved as 'fastf1_race_data.csv'")
# Out:
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '44', '14', '63', '4', '31', '18', '22', '10', '77', '24', '23', '20', '3', '2', '27', '55', '81']
# ✅ Table 'fastf1_race_data' ensured in PostgreSQL
# ✅ Laps data inserted into 'fastf1_race_data'
# ✅ Data successfully read from PostgreSQL table 'fastf1_race_data'
# 💾 Data saved as '2023_Belgium_R_race_data.csv'
# ✅ FastF1 race data saved as 'fastf1_race_data.csv'
# C:\Users\hi\AppData\Local\Temp\ipykernel_4332\2776354147.py:244: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
