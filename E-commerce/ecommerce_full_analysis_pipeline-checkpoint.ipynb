# %%
import pandas as pd
import numpy as np
import seaborn as sns
import psycopg2
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from scipy.stats import chi2_contingency
from scipy.stats import stats
from scipy.stats import f_oneway
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401, needed for 3d projection
ec_data = pd.read_csv('Ecommerce_Delivery_Analytics_New.csv')

# %%
class Ecommerce:
    """
    Ecommerce class for analyzing e-commerce delivery data.
    
    Attributes:
    -----------
    ec_data : pd.DataFrame
        DataFrame containing e-commerce orders and delivery details.
    """
    def __init__(self, ec_data):
        """
        Initialize the ecommerce class with a DataFrame.
        
        Parameters:
        -----------
        ec_data : pd.DataFrame
            The e-commerce dataset.
        """
        self.ec_data = ec_data
        
    def dataframe(self):
        """
        Returns the stored DataFrame.
        
        Returns:
        --------
        pd.DataFrame
            The e-commerce dataset.
        """
        return self.ec_data
        
    def shape(self):
        """
        Returns shape of the DataFrame (rows, columns).
        
        Returns:
        --------
        tuple
            Number of rows and columns.
        """
        return self.ec_data.shape
        
    def type_conversion(self):
        """
        Converts columns to numeric types: 'Delivery Time (Minutes)',
        'Order Value (INR)', 'Service Rating'. Non-convertible values
        become NaN.
        """
        self.ec_data['Delivery Time (Minutes)'] = pd.to_numeric(self.ec_data['Delivery Time (Minutes)'], errors='coerce')
        self.ec_data['Order Value (INR)'] = pd.to_numeric(self.ec_data['Order Value (INR)'], errors='coerce')
        self.ec_data['Service Rating'] = pd.to_numeric(self.ec_data['Service Rating'], errors='coerce')
        
    def describing(self):
        """
        Produces descriptive statistics of numeric columns in the DataFrame.
        
        Returns:
        --------
        pd.DataFrame
            Summary statistics for numeric columns.
        """
        return self.ec_data.describe()
        
    def total_columns(self):
        """
        Returns the list of all column names.
        
        Returns:
        --------
        pd.Index
            Column names in the DataFrame.
        """
        return self.ec_data.columns
    
    def null_values(self):
        """
        Counts null values in each column.
        
        Returns:
        --------
        pd.Series
            Number of null values for each column.
        """
        return self.ec_data.isnull().sum()
    
    def valuecounts(self):
        """
        Returns count of unique values in 'Platform' column.
        
        Returns:
        --------
        pd.DataFrame
            Counts of each unique platform.
        """
        return self.ec_data['Platform'].value_counts().reset_index()
    
    @staticmethod
    def percent_yes(series):
        """
        Calculates the percentage of 'Yes' values in a series.
        
        Parameters:
        -----------
        series : pd.Series
            Series with 'Yes' or other values.
        
        Returns:
        --------
        float
            Percentage of 'Yes' values.
        """
        return 100 * (series == 'Yes').mean()
    
    def compute_platform_metrics(self):
        """
        Computes average delivery time, average service rating,
        % deliveries delayed, and % refunds requested per platform.
        
        Returns:
        --------
        pd.DataFrame
            Aggregated metrics grouped by platform.
        """
        platform_metrics = self.ec_data.groupby('Platform').agg({
            'Delivery Time (Minutes)': 'mean',
            'Service Rating': 'mean',
            'Delivery Delay': self.percent_yes,
            'Refund Requested': self.percent_yes
        }).rename(columns={
            'Delivery Time (Minutes)': 'Avg Delivery Time (min)',
            'Service Rating': 'Avg Service Rating',
            'Delivery Delay': '% Deliveries Delayed',
            'Refund Requested': '% Refund Requested'
        }).round(2)
        return platform_metrics
    
    def category_delay_stats(self):
        """
        Calculates percentage of deliveries delayed by product category.
        
        Returns:
        --------
        pd.DataFrame
            Percentage delayed per product category.
        """
        category_delay = self.ec_data.groupby('Product Category').agg({
            'Delivery Delay': self.percent_yes
        }).rename(columns={'Delivery Delay': '% Delayed'}).sort_values('% Delayed', ascending=False)
        return category_delay
    
    def Average_delivery_time(self):
        """
        Prints average delivery time grouped by delivery delay status.
        """
        delay_vs_time = self.ec_data.groupby('Delivery Delay')['Delivery Time (Minutes)'].mean().round(2)
        print(delay_vs_time)
    
    def Average_service_rating(self):
        """
        Prints average delivery time grouped by service rating.
        """
        rating_vs_time = self.ec_data.groupby('Service Rating')['Delivery Time (Minutes)'].mean()
        print(rating_vs_time)
    
    def minimum(self):
        """
        Returns minimum delivery time per customer sorted ascending.
        
        Returns:
        --------
        pd.DataFrame
            Customers and their minimum delivery times.
        """
        return self.ec_data.groupby('Customer ID')['Delivery Time (Minutes)'].min().reset_index().sort_values(by='Delivery Time (Minutes)', ascending=True)

    def Chi_Square_test(self, col1, col2):
        """
        Perform Chi-Square test of independence between two categorical columns.

        Parameters:
        -----------
        col1 : str
            Name of the first categorical column.
        col2 : str
            Name of the second categorical column.

        Returns:
        --------
        dict
            Dictionary containing chi-square statistic, p-value, degrees of freedom,
            and expected frequencies matrix.
        """
        contingency_table = pd.crosstab(self.ec_data[col1], self.ec_data[col2])
        chi2, p, dof, expected = chi2_contingency(contingency_table)
        return {
            'chi2_statistic': chi2,
            'p_value': p,
            'degrees_of_freedom': dof,
            'expected_freq': expected
        }

    def line_plot(self):
        plt.figure(figsize=(15,10))
        sns.lineplot(data=self.ec_data, x="Product Category", y="Delivery Time (Minutes)")
        plt.show()
    
    def scatter_plot(self):
        plt.figure(figsize=(20,40))
        sns.scatterplot(data=self.ec_data, x="Order Value (INR)", y="Delivery Time (Minutes)")
        plt.show()
    
    def bar_plot(self):
        avg_ratings = self.ec_data.groupby("Platform")["Service Rating"].mean().reset_index()
        sns.barplot(data=avg_ratings, x="Platform", y="Service Rating")
        plt.title("Average Service Rating by Platform")
        plt.show()
    
    def violin_plot(self):
        sns.violinplot(data=self.ec_data, x="Platform", y="Service Rating")
        plt.title("Service Rating by Platform")
        plt.show()
    
    def histogram(self, col):
        sns.histplot(data=self.ec_data, x=col, bins=20, color="skyblue")
        plt.show()
    
    def correlation(self):
        sns.heatmap(self.ec_data[['Order Value (INR)', 'Service Rating', 'Delivery Time (Minutes)']].corr(), annot=True)
        plt.show()
    
    def piechart(self):
        platform_counts = self.ec_data['Platform'].value_counts()
        plt.pie(platform_counts, labels=platform_counts.index, autopct='%1.1f%%', startangle=140)
        plt.title("Order Share by Platform")
        plt.axis('equal')
        plt.show()

    def ANOVA(self):
        continuous_vars = self.ec_data.select_dtypes(include=['int64', 'float64']).columns.tolist()
        target = 'Refund Requested'
        for col in continuous_vars:
            data = self.ec_data[[col, target]].dropna()
            groups = [group[col].values for name, group in data.groupby(target)]
            if len(groups) > 1:
                f_stat, p_val = stats.f_oneway(*groups)
                print(f"ANOVA for {col} by {target}: F = {f_stat:.3f}, p = {p_val:.3e}")
            else:
                print(f"Insufficient groups for {col} to perform ANOVA.")

    def plot_numeric_correlation(self, figsize=(12, 10), cmap='coolwarm'):
        numeric_df = self.ec_data.select_dtypes(include=np.number)
        corr = numeric_df.corr()
        plt.figure(figsize=figsize)
        sns.heatmap(corr, annot=True, cmap=cmap)
        plt.show()

    @staticmethod
    def infer_sql_type(dtype):
        if pd.api.types.is_integer_dtype(dtype):
            return "INT"
        elif pd.api.types.is_float_dtype(dtype):
            return "FLOAT"
        elif pd.api.types.is_bool_dtype(dtype):
            return "BOOLEAN"
        elif pd.api.types.is_datetime64_any_dtype(dtype):
            return "TIMESTAMP"
        else:
            return "TEXT"
    
    def generate_create_table_statement(self, table_name="Ecommerce_Delivery_Analytics_New"):
        columns = self.ec_data.dtypes
        sql_columns = ",\n    ".join([f'"{col}" {self.infer_sql_type(dtype)}' for col, dtype in columns.items()])
        create_stmt = f"""
    CREATE TABLE IF NOT EXISTS {table_name} (
        {sql_columns}
    );
    """
        return create_stmt

    def save_to_postgres(self, conn_params, table_name="Ecommerce_Delivery_Analytics_New"):
        create_stmt = self.generate_create_table_statement(table_name)
        try:
            conn = psycopg2.connect(**conn_params)
            cur = conn.cursor()
            cur.execute(create_stmt)
            conn.commit()
            columns = list(self.ec_data.columns)
            placeholders = ', '.join(['%s'] * len(columns))
            insert_stmt = f"""
            INSERT INTO {table_name} ({', '.join(['"{}"'.format(col) for col in columns])})
            VALUES ({placeholders})
            """
            for _, row in self.ec_data.iterrows():
                cur.execute(insert_stmt, tuple(row))
            conn.commit()
            cur.close()
            conn.close()
            print(f"Data inserted successfully into table {table_name}")
        except Exception as e:
            print(f"Error during PostgreSQL operation: {e}")

# Usage
obj_ec = Ecommerce(ec_data)

# %%
obj_ec.dataframe()
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# 3                           42            Beverages                946
# 4                           30            Beverages                334
# ...                        ...                  ...                ...
# 99995                       24                Dairy                289
# 99996                       19               Snacks                322
# 99997                       41                Dairy                135
# 99998                       31              Grocery                973
# 99999                       34  Fruits & Vegetables                453
#
#                    Customer Feedback  Service Rating Delivery Delay  \
# 0      Fast delivery, great service!               5             No
# 1                Quick and reliable!               5             No
# 2          Items missing from order.               2             No
# 3          Items missing from order.               2            Yes
# 4      Fast delivery, great service!               5             No
# ...                              ...             ...            ...
# 99995     Packaging could be better.               3             No
# 99996         Good quality products.               4             No
# 99997  Fast delivery, great service!               5            Yes
# 99998            Quick and reliable!               5             No
# 99999     Packaging could be better.               3             No
#
#       Refund Requested
# 0                   No
# 1                   No
# 2                  Yes
# 3                  Yes
# 4                   No
# ...                ...
# 99995               No
# 99996               No
# 99997               No
# 99998               No
# 99999               No
#
# [100000 rows x 11 columns]

# %%
obj_ec.shape()
# Out:
# (100000, 11)

# %%
obj_ec.describing()
# Out:
#        Delivery Time (Minutes)  Order Value (INR)  Service Rating
# count            100000.000000      100000.000000   100000.000000
# mean                 29.536140         590.994400        3.240790
# std                   9.958933         417.409058        1.575962
# min                   5.000000          50.000000        1.000000
# 25%                  23.000000         283.000000        2.000000
# 50%                  30.000000         481.000000        3.000000
# 75%                  36.000000         770.000000        5.000000
# max                  76.000000        2000.000000        5.000000

# %%
obj_ec.valuecounts()
# Out:
#            Platform  count
# 0  Swiggy Instamart  33449
# 1           Blinkit  33424
# 2           JioMart  33127

# %%
obj_ec.total_columns()
# Out:
# Index(['Order ID', 'Customer ID', 'Platform', 'Order Date & Time',
#        'Delivery Time (Minutes)', 'Product Category', 'Order Value (INR)',
#        'Customer Feedback', 'Service Rating', 'Delivery Delay',
#        'Refund Requested'],
#       dtype='object')

# %%
obj_ec.null_values()
# Out:
# Order ID                   0
# Customer ID                0
# Platform                   0
# Order Date & Time          0
# Delivery Time (Minutes)    0
# Product Category           0
# Order Value (INR)          0
# Customer Feedback          0
# Service Rating             0
# Delivery Delay             0
# Refund Requested           0
# dtype: int64

# %%
obj_ec.compute_platform_metrics()
# Out:
#                   Avg Delivery Time (min)  Avg Service Rating  \
# Platform
# Blinkit                             29.47                3.23
# JioMart                             29.63                3.25
# Swiggy Instamart                    29.50                3.24
#
#                   % Deliveries Delayed  % Refund Requested
# Platform
# Blinkit                          13.38               45.93
# JioMart                          13.83               45.82
# Swiggy Instamart                 13.81               45.71

# %%
obj_ec.category_delay_stats()
# Out:
#                      % Delayed
# Product Category
# Grocery              13.819681
# Fruits & Vegetables  13.768639
# Dairy                13.715370
# Personal Care        13.633339
# Snacks               13.570787
# Beverages            13.522013

# %%
obj_ec.Average_delivery_time()
# Out:
# Delivery Delay
# No     27.00
# Yes    45.56
# Name: Delivery Time (Minutes), dtype: float64

# %%
obj_ec.Average_service_rating()
# Out:
# Service Rating
# 1    29.518766
# 2    29.556592
# 3    29.428349
# 4    29.617538
# 5    29.531922
# Name: Delivery Time (Minutes), dtype: float64

# %%
obj_ec.minimum()
# Out:
#      Customer ID  Delivery Time (Minutes)
# 54      CUST1054                        5
# 8559    CUST9559                        5
# 81      CUST1081                        5
# 74      CUST1074                        5
# 7820    CUST8820                        5
# ...          ...                      ...
# 5769    CUST6769                       32
# 3576    CUST4576                       33
# 1187    CUST2187                       33
# 239     CUST1239                       34
# 3988    CUST4988                       36
#
# [9000 rows x 2 columns]

# %%
obj_ec.line_plot()

# %%
obj_ec.scatter_plot()

# %%
obj_ec.violin_plot()

# %%
obj_ec.histogram("Order Value (INR)")

# %%
obj_ec.correlation()

# %%
obj_ec.piechart()

# %%
obj_ec.Chi_Square_test('Platform','Product Category')
# Out:
# {'chi2_statistic': np.float64(6.689176343244628),
#  'p_value': np.float64(0.7544265224965951),
#  'degrees_of_freedom': 10,
#  'expected_freq': array([[5526.99264, 5634.28368, 5559.07968, 5594.17488, 5525.98992,
#          5583.4792 ],
#         [5477.88072, 5584.21839, 5509.68264, 5544.46599, 5476.88691,
#          5533.86535],
#         [5531.12664, 5638.49793, 5563.23768, 5598.35913, 5530.12317,
#          5587.65545]])}

# %%
obj_ec.ANOVA()
# Out:
# ANOVA for Delivery Time (Minutes) by Refund Requested: F = 0.053, p = 8.187e-01
# ANOVA for Order Value (INR) by Refund Requested: F = 0.702, p = 4.020e-01
# ANOVA for Service Rating by Refund Requested: F = 539219.357, p = 0.000e+00
# C:\Users\hi\AppData\Local\Temp\ipykernel_12444\4195076654.py:245: DeprecationWarning: Please import `f_oneway` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   f_stat, p_val = stats.f_oneway(*groups)
# C:\Users\hi\AppData\Local\Temp\ipykernel_12444\4195076654.py:245: DeprecationWarning: Please import `f_oneway` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   f_stat, p_val = stats.f_oneway(*groups)
# C:\Users\hi\AppData\Local\Temp\ipykernel_12444\4195076654.py:245: DeprecationWarning: Please import `f_oneway` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   f_stat, p_val = stats.f_oneway(*groups)

# %%
obj_ec.plot_numeric_correlation()

# %%
print(obj_ec.generate_create_table_statement())
# Out:
#     CREATE TABLE IF NOT EXISTS Ecommerce_Delivery_Analytics_New (
#         "Order ID" TEXT,
#     "Customer ID" TEXT,
#     "Platform" TEXT,
#     "Order Date & Time" TEXT,
#     "Delivery Time (Minutes)" INT,
#     "Product Category" TEXT,
#     "Order Value (INR)" INT,
#     "Customer Feedback" TEXT,
#     "Service Rating" INT,
#     "Delivery Delay" TEXT,
#     "Refund Requested" TEXT
#     );

# %%
conn_params = {
    'dbname': "postgres",
    'user': "postgres",
    'password': "901473R",
    'host': "localhost",
    'port': "5432"
}
obj_ec.save_to_postgres(conn_params)
# Out:
# Data inserted successfully into table Ecommerce_Delivery_Analytics_New
