# %%
import pandas as pd
import numpy as np

# %%
ec_df = pd.read_csv('Ecommerce_Delivery_Analytics_New.csv')
ec_df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
ec_df['Platform'].unique()
# Out:
# array(['JioMart', 'Blinkit', 'Swiggy Instamart'], dtype=object)

# %%
ec_df['Platform'].value_counts()
# Out:
# Platform
# Swiggy Instamart    33449
# Blinkit             33424
# JioMart             33127
# Name: count, dtype: int64

# %%
ec_df.groupby('Platform')['Delivery Time (Minutes)'].mean()
# Out:
# Platform
# Blinkit             29.474898
# JioMart             29.634498
# Swiggy Instamart    29.499925
# Name: Delivery Time (Minutes), dtype: float64

# %%
ec_df.groupby('Platform')['Delivery Time (Minutes)'].median()
# Out:
# Platform
# Blinkit             30.0
# JioMart             30.0
# Swiggy Instamart    29.0
# Name: Delivery Time (Minutes), dtype: float64

# %%
ec_df['Delivery Time (Minutes)'].mode()
# Out:
# 0    31
# Name: Delivery Time (Minutes), dtype: int64

# %%
ec_df.groupby('Platform')['Delivery Time (Minutes)'].mean()
# Out:
# Platform
# Blinkit             29.474898
# JioMart             29.634498
# Swiggy Instamart    29.499925
# Name: Delivery Time (Minutes), dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(ec_df['Platform'],bins = 100)
plt.xlabel('Platform')
plt.ylabel('Delivery Time (Minutes)')
plt.title('Histogram of SalePrice')
# Out:
# Text(0.5, 1.0, 'Histogram of SalePrice')

# %%
import seaborn as sns
sns.histplot(ec_df['Order Value (INR)'], bins=100)
plt.show()

# %%
# Filter rows: Orders with delivery time > 30 minutes

ec_df[ec_df['Delivery Time (Minutes)'] > 30]
# Out:
#         Order ID Customer ID          Platform Order Date & Time  \
# 3      ORD000004    CUST5012           JioMart           19:29.5
# 8      ORD000009    CUST2424           JioMart           51:29.5
# 9      ORD000010    CUST7912           JioMart           08:29.5
# 12     ORD000013    CUST2535           Blinkit           08:29.5
# 14     ORD000015    CUST4811  Swiggy Instamart           27:29.5
# ...          ...         ...               ...               ...
# 99993  ORD099994    CUST5305           JioMart           34:29.5
# 99994  ORD099995    CUST1984           JioMart           45:29.5
# 99997  ORD099998    CUST8198           JioMart           27:29.5
# 99998  ORD099999    CUST9975           JioMart           14:29.5
# 99999  ORD100000    CUST3748           JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 3                           42            Beverages                946
# ...

# %%
 # Select columns: Show only Order ID and Delivery Time

ec_df[['Order ID', 'Delivery Time (Minutes)']]
# Out:
#         Order ID  Delivery Time (Minutes)
# 0      ORD000001                       30
# 1      ORD000002                       16
# 2      ORD000003                       25
# 3      ORD000004                       42
# 4      ORD000005                       30
# ...          ...                      ...
# 99995  ORD099996                       24
# 99996  ORD099997                       19
# 99997  ORD099998                       41
# 99998  ORD099999                       31
# 99999  ORD100000                       34
#
# [100000 rows x 2 columns]

# %%
# Sort data: Orders sorted by Delivery Time (highest first)

ec_df.sort_values(by='Delivery Time (Minutes)', ascending=True)
# Out:
#         Order ID Customer ID          Platform Order Date & Time  \
# 8037   ORD008038    CUST3255  Swiggy Instamart           31:29.5
# 27835  ORD027836    CUST2366           Blinkit           33:29.5
# 28133  ORD028134    CUST9271  Swiggy Instamart           38:29.5
# 88023  ORD088024    CUST5373           JioMart           49:29.5
# 2371   ORD002372    CUST2260           Blinkit           02:29.5
# ...          ...         ...               ...               ...
# 22270  ORD022271    CUST6864           JioMart           51:29.5
# 93165  ORD093166    CUST2755           Blinkit           59:29.5
# 95583  ORD095584    CUST8737           JioMart           43:29.5
# 49802  ORD049803    CUST2646           JioMart           01:29.5
# 47735  ORD047736    CUST4744           Blinkit           11:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 8037                         5               Snacks                496
# ...

# %%
# Group by platform and calculate average delivery time
ec_df.groupby('Platform')['Delivery Time (Minutes)'].mean()
# Out:
# Platform
# Blinkit             29.474898
# JioMart             29.634498
# Swiggy Instamart    29.499925
# Name: Delivery Time (Minutes), dtype: float64

# %%
# Count rows: Total number of orders
len(ec_df)
# Out:
# 100000

# %%
ec_df.shape[0]
# Out:
# 100000

# %%
ec_df.shape[1]
# Out:
# 11

# %%
ec_df.count()
# Out:
# Order ID                   100000
# Customer ID                100000
# Platform                   100000
# Order Date & Time          100000
# Delivery Time (Minutes)    100000
# Product Category           100000
# Order Value (INR)          100000
# Customer Feedback          100000
# Service Rating             100000
# Delivery Delay             100000
# Refund Requested           100000
# dtype: int64

# %%
# Mean & Sum: Average and total order value
ec_df['Order Value (INR)'].mean()
# Out:
# np.float64(590.9944)

# %%
ec_df['Order Value (INR)'].sum()
# Out:
# np.int64(59099440)

# %%
# Remove duplicates: Remove duplicate orders
ec_df.drop_duplicates()
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
# Rename columns: Rename "Order Value (INR)" to "Order Amount"
ec_df.rename(columns={'Order Value (INR)': 'Order Amount'})
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Amount  \
# 0                           30  Fruits & Vegetables           382
# 1                           16                Dairy           279
# 2                           25            Beverages           599
# ...

# %%
# Change data type: Convert 'Service Rating' to float
ec_df['Service Rating'] = ec_df['Service Rating'].astype(float)
ec_df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
# Handle missing values (if any)
ec_df.isnull().sum() # Check missing
# Out:
# Order ID                   0
# Customer ID                0
# Platform                   0
# Order Date & Time          0
# Delivery Time (Minutes)    0
# Product Category           0
# Order Value (INR)          0
# Customer Feedback          0
# Service Rating             0
# Delivery Delay             0
# Refund Requested           0
# dtype: int64

# %%
# Pivot table: Avg delivery time per product category per platform
pd.pivot_table(ec_df, values='Delivery Time (Minutes)', index='Platform', columns='Product Category', aggfunc='mean')
# Out:
# Product Category  Beverages      Dairy  Fruits & Vegetables    Grocery  \
# Platform
# Blinkit           29.574647  29.512493            29.276004  29.448264
# JioMart           29.620218  29.590584            29.729715  29.728992
# Swiggy Instamart  29.317607  29.579247            29.650817  29.564190
#
# Product Category  Personal Care     Snacks
# Platform
# Blinkit               29.773018  29.269818
# JioMart               29.612767  29.523182
# Swiggy Instamart      29.336528  29.552599

# %%
ec_df['Service Rating'].fillna(ec_df['Service Rating'].mean())  # Fill with mean
# Out:
# 0        5.0
# 1        5.0
# 2        2.0
# 3        2.0
# 4        5.0
#         ...
# 99995    3.0
# 99996    4.0
# 99997    5.0
# 99998    5.0
# 99999    3.0
# Name: Service Rating, Length: 100000, dtype: float64

# %%
# Add new column: Fast or Slow delivery based on delivery time
ec_df['Delivery Speed'] = ['Fast' if x <= 30 else 'Slow' for x in ec_df['Delivery Time (Minutes)']]
ec_df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
# Add new column: Fast or Slow delivery based on delivery time
ec_df['Delivery Speed'] = ['Fast' if x <= 30 else 'Slow' for x in ec_df['Delivery Time (Minutes)']]
ec_df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...
